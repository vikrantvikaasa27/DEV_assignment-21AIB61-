# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# EDA

# %%
df=pd.read_csv('/content/International_Report_Passengers.csv')
df1=df.head(400)

# %%
df1.describe()
# Out:
#               Year      Month    usg_apt_id     usg_wac     fg_apt_id  \
# count   400.000000  400.00000    400.000000  400.000000    400.000000
# mean   2005.332500    6.06250  13037.915000   41.032500  13444.122500
# std       2.859613    3.63202   4599.880246   24.518449   2076.832497
# min    2001.000000    1.00000  10140.000000    1.000000  10148.000000
# 25%    2003.000000    3.00000  11433.000000   23.000000  11202.250000
# 50%    2005.000000    6.00000  13232.000000   34.000000  13605.000000
# 75%    2008.000000    9.00000  13930.250000   63.000000  15219.750000
# max    2014.000000   12.00000  99999.000000   93.000000  16322.000000
#
#            fg_wac     airlineid  carriergroup  Scheduled       Charter  \
# count  400.000000    400.000000    400.000000      400.0    400.000000
# mean   427.887500  20266.347500      0.695000        0.0    804.477500
# std    306.745664    382.930851      0.460984        0.0   1462.620186
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      400 non-null    object
#  1   Year          400 non-null    int64
#  2   Month         400 non-null    int64
#  3   usg_apt_id    400 non-null    int64
#  4   usg_apt       400 non-null    object
#  5   usg_wac       400 non-null    int64
#  6   fg_apt_id     400 non-null    int64
#  7   fg_apt        400 non-null    object
#  8   fg_wac        400 non-null    int64
#  9   airlineid     400 non-null    int64
#  10  carrier       395 non-null    object
#  11  carriergroup  400 non-null    int64
#  12  type          400 non-null    object
#  13  Scheduled     400 non-null    int64
#  14  Charter       400 non-null    int64
#  15  Total         400 non-null    int64
# dtypes: int64(11), object(5)
# memory usage: 50.1+ KB

# %%
df1.shape
# Out:
# (400, 16)

# %%
d=df1['Year'].mean()
d
# Out:
# 2005.3325

# %%
df1.nunique()
# Out:
# data_dte        116
# Year             11
# Month            12
# usg_apt_id      113
# usg_apt         113
# usg_wac          44
# fg_apt_id       125
# fg_apt          125
# fg_wac           55
# airlineid        82
# carrier          85
# carriergroup      2
# type              1
# Scheduled         1
# Charter         299
# Total           299
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         5
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %%
df1.loc[df1["airlineid"] == 20414, "carrier"] = 'OW'
df1.loc[df1["airlineid"] == 20415, "carrier"] = 'XG'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df1.isnull().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         0
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %% [markdown]
# VISUALIZATION

# %%
plt.bar(df1['usg_wac'],df1['fg_wac'] ,color='b')
plt.xlabel("usg_wac")
plt.ylabel("fg_wac")
plt.title("International Report Passengers")
plt.legend()
plt.show
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df1.plot.bar(stacked=True)

# %%
df1.plot(kind='bar')

# %%
df1.plot.area()

# %%
plt.hist(df1['usg_wac'],color='blue')
plt.title('usg_wac histogram')
# Out:
# Text(0.5, 1.0, 'usg_wac histogram')

# %%
sns.displot(df1['Month'],bins=30)

# %%
sns.heatmap(df1.corr())

# %%
df1.plot(kind="scatter",x="airlineid",y="fg_wac")

# %%
df1.plot.box()

# %%
x=df1.usg_wac
plt.pie(x)
plt.show()

# %%
plt.polar(x)
plt.show()
